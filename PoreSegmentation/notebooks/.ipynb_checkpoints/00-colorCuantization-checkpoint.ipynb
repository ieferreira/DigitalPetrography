# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from sklearn.datasets import make_blobs, make_circles, make_moons
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics
from collections import Counter
from pylab import rcParams

rcParams['figure.figsize'] = 10, 10

# %%
img = plt.imread("../imgs/porosidadalta.jpg")

rcParams["figure.figsize"] = 10,10
plt.imshow(img)

# %%
img.shape
# Out:
# (529, 802, 3)

# %%
img[:2]
# Out:
# array([[[ 18, 140, 164],
#         [ 11, 131, 156],
#         [  7, 122, 149],
#         ...,
#         [158,  58,  86],
#         [160,  54, 103],
#         [176,  70, 119]],
#
#        [[ 22, 146, 170],
#         [ 15, 139, 163],
#         [ 12, 132, 157],
#         ...,
#         [159,  58,  90],
#         [161,  53, 102],
#         [177,  69, 118]]], dtype=uint8)

# %%
img = img/255
img.shape
# Out:
# (529, 802, 3)

# %%
img[:2]
# Out:
# array([[[0.07058824, 0.54901961, 0.64313725],
#         [0.04313725, 0.51372549, 0.61176471],
#         [0.02745098, 0.47843137, 0.58431373],
#         ...,
#         [0.61960784, 0.22745098, 0.3372549 ],
#         [0.62745098, 0.21176471, 0.40392157],
#         [0.69019608, 0.2745098 , 0.46666667]],
#
#        [[0.08627451, 0.57254902, 0.66666667],
#         [0.05882353, 0.54509804, 0.63921569],
#         [0.04705882, 0.51764706, 0.61568627],
#         ...,
#         [0.62352941, 0.22745098, 0.35294118],
#         [0.63137255, 0.20784314, 0.4       ],
#         [0.69411765, 0.27058824, 0.4627451 ]]])

# %%
m, l, k = img.shape[0], img.shape[1], img.shape[2]

df = pd.DataFrame(img.reshape(m*l,k))
print(df)
# Out:
#                0         1         2
# 0       0.070588  0.549020  0.643137
# 1       0.043137  0.513725  0.611765
# 2       0.027451  0.478431  0.584314
# 3       0.035294  0.462745  0.576471
# 4       0.050980  0.443137  0.568627
# ...          ...       ...       ...
# 424253  0.780392  0.388235  0.247059
# 424254  0.788235  0.388235  0.231373
# 424255  0.796078  0.392157  0.223529
# 424256  0.764706  0.427451  0.243137
# 424257  0.811765  0.474510  0.290196
#
# [424258 rows x 3 columns]

# %%
df.columns = ["R", "G", "B"]
print(df.head())
# Out:
#           R         G         B
# 0  0.070588  0.549020  0.643137
# 1  0.043137  0.513725  0.611765
# 2  0.027451  0.478431  0.584314
# 3  0.035294  0.462745  0.576471
# 4  0.050980  0.443137  0.568627

# %%
n_clusters = 3
kmeans = KMeans(n_clusters = n_clusters)
kmeans.fit(df)
df["clusters"] = kmeans.labels_

# %%
df.sample(5)
# Out:
#                R         G         B  clusters
# 15765   0.423529  0.313725  0.545098         2
# 345222  0.039216  0.623529  0.607843         0
# 153964  0.062745  0.635294  0.635294         0
# 138981  0.062745  0.568627  0.588235         0
# 30126   0.105882  0.227451  0.305882         2

# %%
colors = df.groupby(["clusters"]).mean()
colors
# Out:
#                  R         G         B
# clusters
# 0         0.026128  0.645679  0.751529
# 1         0.757600  0.365274  0.335676
# 2         0.301093  0.330219  0.434565

# %%
index_larger = colors.sort_values(by=["B"], ascending=False)

# %%
por = index_larger.iloc[0].name

# %%
s=df.clusters.value_counts(normalize=True,sort=False).mul(100) # mul(100) is == *100

print(s) #series.to_frame() returns a dataframe
# Out:
# 0    43.014628
# 1    42.573151
# 2    14.412221
# Name: clusters, dtype: float64

# %%
print(s.loc[por])
# Out:
# 43.01462789151884

# %%
centers = pd.DataFrame(kmeans.cluster_centers_)
centers["clusters"] = range(n_clusters)

# %%
df["ind"] = df.index
df = df.merge(centers)
df = df.sort_values("ind")
df = df.drop("ind", 1)

# %%
quant_img = df.iloc[:,4:7].values

quant_img = quant_img.reshape(img.shape[0], img.shape[1], img.shape[2])

# %%
plt.imshow(quant_img)

# %%
again_img = quant_img*255
print(again_img)
# Out:
# [[[  6.66963425 164.64032368 191.63236873]
#   [  6.66963425 164.64032368 191.63236873]
#   [  6.66963425 164.64032368 191.63236873]
#   ...
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]]
#
#  [[  6.66963425 164.64032368 191.63236873]
#   [  6.66963425 164.64032368 191.63236873]
#   [  6.66963425 164.64032368 191.63236873]
#   ...
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]]
#
#  [[  6.66963425 164.64032368 191.63236873]
#   [  6.66963425 164.64032368 191.63236873]
#   [  6.66963425 164.64032368 191.63236873]
#   ...
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]]
#
#  ...
#
#  [[193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   ...
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]]
#
#  [[193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   ...
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]]
#
#  [[193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   ...
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]
#   [193.1802687   93.15056436  85.60664168]]]

# %%
df2 = pd.DataFrame(again_img.reshape(m*l,k))
df2.columns = ["R", "G", "B"]

# %%
print(df2)
# Out:
#                  R           G           B
# 0         6.669634  164.640324  191.632369
# 1         6.669634  164.640324  191.632369
# 2         6.669634  164.640324  191.632369
# 3         6.669634  164.640324  191.632369
# 4         6.669634  164.640324  191.632369
# ...            ...         ...         ...
# 424253  193.180269   93.150564   85.606642
# 424254  193.180269   93.150564   85.606642
# 424255  193.180269   93.150564   85.606642
# 424256  193.180269   93.150564   85.606642
# 424257  193.180269   93.150564   85.606642
#
# [424258 rows x 3 columns]

# %%
print(df2.R.unique())
print(df2.G.unique())
print(df2.B.unique())
# Out:
# [  6.66963425  76.76882275 193.1802687 ]
# [164.64032368  84.16238561  93.15056436]
# [191.63236873 110.7737341   85.60664168]

# %%
contados = df2.apply(pd.value_counts).sum(axis=1)
print(contados)
# Out:
# 6.669634      182493.0
# 76.768823      61145.0
# 84.162386      61145.0
# 85.606642     180620.0
# 93.150564     180620.0
# 110.773734     61145.0
# 164.640324    182493.0
# 191.632369    182493.0
# 193.180269    180620.0
# dtype: float64

# %%
total = pd.unique(contados)
print(total)
# Out:
# [182493.  61145. 180620.]

# %%
suma = total.sum()
porcentaje = (total/suma)*100
print(porcentaje)
print("______________________ \n")
print("POROSIDAD = ", porcentaje[0])
# Out:
# [43.01462789 14.41222087 42.57315124]
# ______________________
#
# POROSIDAD =  43.01462789151884
